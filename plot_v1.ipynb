# %%
# Necessary imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from datetime import datetime, timedelta
import shutil
# Out:
# /Users/yuchenma/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# Documentations for this function overall:
# 1. data_generation: taking in a paramter of path to data and target frequency of this dataset (only support daily and hourly data), returns a dataframe that has parsed the data. Could add in additional features if wanted.
# 2. charts will initialize mainly out of default parameters, the important ones are data(dataframe that we want to plot), freq(frequency of the data), additional_cols(all additional feature column names), other_cols_color(specifiy the corresponding colors for all additional columns in RGB fashion), overlap(meaning if we want the plots to contain overlapping dates or not)
# 3. charts.generate is the main function generating all the plots, taking in two parameters, "benchmark" (if True, then the plots will only contain OHLC; if False, will plot all features specified in initialization) and "make_up_short" (if True, we will randomly select plots with label -1 and duplicate them in order to make the short plots about 50% of the whole training dataset)

# %%
# Add in additional features here if needed
def data_generation(data_path, freq):
    if freq == 'D':
        data = pd.read_csv(data_path, index_col=0, parse_dates=True)
    elif freq == 'H':
        data = pd.read_csv(data_path, index_col=0)
        incr = 1e-9
        unix_start = datetime(1970, 1, 1)
        date = []
        for i in range(len(data)):
            date.append(unix_start + timedelta(seconds=incr*data.index[i]))
        data.index = date
        for col in ['open', 'high', 'low', 'close']:
            data[col] = data[col].astype(float) * incr
    # Add features here
    
    data.columns = data.columns.str.lower()
    return data

# %%
class charts():
    def __init__(self,
                 data,
                 symbol,
                 window_size=60,
                 additional_cols=[],
                 other_cols_color=[],
                 freq='D',
                 percent_train=0.7,
                 overlap=True,
                 ):
        assert len(additional_cols) == len(other_cols_color)
        self.data = data.copy()
        self.symbol = symbol
        self.overlap = overlap

        self.window_size = window_size
        self.multiple = 1 if freq == 'D' else 16

        # Changed: symbol is now a defined input
        # Set the symbol for the data, default is SPY
        # self.symbol = 'SPY'
        # if 'symbol' in data.columns:
        #     self.symbol = data['symbol'].iloc[0]
        #     data.drop('symbol', axis=1, inplace=True)

        # Resample at the desired frequency, default is daily (only support daily and hourly)
        self.freq = freq

        # Set all column names
        self.feat_cols = ['open', 'high', 'low', 'close'] + additional_cols
        self.other_cols = additional_cols
        self.other_cols_color = other_cols_color
        self.cutoff = percent_train

    # Main function
    def plot(self, df, benchmark):
        if self.window_size == 60:
            const = np.array([76, 19, 96])
        elif self.window_size == 20:
            const = np.array([51, 12, 64])
        elif self.window_size == 5:
            const = np.array([25, 6, 32])
        const *= self.multiple
        df = df.reset_index(drop=True).copy()
        high = df[['high'] + self.other_cols].values.max()
        low = df[['low'] + self.other_cols].values.min()
        for col in self.feat_cols:
            df[col] = (df[col] - low) / (high - low) * const[0]
            df[col] = df[col].round(0).astype(int) + int(const[1])

        df['volume'] = df['volume'] / df['volume'].max() * const[1]
        df['volume'] = df['volume'].round(0).astype(int)

        plot = np.zeros((const[-1], 3 * self.window_size * self.multiple, 3))

        for idx, row in df.iterrows():
            plot[int(row['open']), idx*3, :] = [255] * 3
            plot[int(row['low']):int(row['high']+1), idx*3+1, :] = [255] * 3
            plot[int(row['close']):int(row['close']+1), idx*3+2, :] = [255] * 3
            if not benchmark:
                plot[:int(row['volume']+1), idx*3+1, :] = [255] * 3

                # for col in self.ma_cols:
                #     pre_ma = df.loc[idx-1, col] if idx >= 1 else df.loc[idx, col]
                #     next_ma = df.loc[idx+1, col] if idx <= len(df)-2 else df.loc[idx, col]

                #     plot[int((row[col] + pre_ma)//2), idx*3, :] = [255] * 3
                #     plot[int(row[col]), idx*3+1, :] = [255] * 3
                #     plot[int((row[col] + next_ma)//2), idx*3+2, :] = [255] * 3
                
                for i, col in enumerate(self.other_cols):
                    pre = df.loc[idx-1, col] if idx >= 1 else df.loc[idx, col]
                    nex = df.loc[idx+1, col] if idx <= len(df)-2 else df.loc[idx, col]

                    plot[int((row[col] + pre)//2), idx*3, :] = self.other_cols_color[i]
                    plot[int(row[col]), idx*3+1, :] = self.other_cols_color[i]
                    plot[int((row[col] + nex)//2), idx*3+2, :] = self.other_cols_color[i]

        plot = plot[::-1, :, :]  # reversion
        plot = plot / 255.0

        return plot
    
    def generate(self, train_name, test_name, benchmark=False, make_up_short=False):
        m, _ = self.data.shape
        counter = 0
        last_counter = 0
        short_plot = []
        short_info = []
        short_cnt, long_cnt = 0, 0
        incr = self.window_size * self.multiple
        counter_incr = 12 if self.overlap else incr

        # Changed: train_name and test_name are now parameters to define
        # train_name = 'train' if not benchmark else 'train_benchmark'
        # test_name = 'test' if not benchmark else 'test_benchmark'
        # if os.path.exists(train_name):
        #     shutil.rmtree(train_name)
        # os.makedirs(train_name)
        # if os.path.exists(test_name):
        #     shutil.rmtree(test_name)
        # os.makedirs(test_name)
        train_test_cutoff = int(self.cutoff * m)
        while last_counter < train_test_cutoff:
            curr_plot = self.plot(self.data.iloc[counter:counter+incr, :].copy(), benchmark)
            counter += counter_incr
            last_counter += incr
            curr_dir = []
            for i in [5, 10, 15]:
                if self.data.iloc[counter + i + 1, :].loc['close'] > self.data.iloc[counter + 1, :].loc['close']:
                    curr_dir.append(1)
                else:
                    curr_dir.append(-1)
            plt.imshow(curr_plot)
            plt.axis('off')
            plt.savefig(f"{train_name}/{self.symbol}_{self.window_size}_{self.freq}_{curr_dir[0]}_{curr_dir[1]}_{curr_dir[2]}_{self.data.index.values[counter]}_version_1.png", bbox_inches='tight', pad_inches=0)
            plt.close()
            if curr_dir[0] == 1:
                long_cnt += 1
            else:
                short_cnt += 1
                short_plot.append(curr_plot)
                short_info.append((curr_dir, self.data.index.values[counter]))
        if make_up_short:
            if short_cnt / (long_cnt + short_cnt) < 0.5:
                target = int(0.5 * (long_cnt + short_cnt) - short_cnt)
                for i in range(target):
                    rand_ind = np.random.randint(0, len(short_plot))
                    tmp_plot = short_plot[rand_ind]
                    tmp_dir, tmp_end = short_info[rand_ind]
                    plt.imshow(tmp_plot)
                    plt.axis('off')
                    # plt.show()
                    plt.savefig(f"{train_name}/{self.symbol}_{self.window_size}_{self.freq}_{tmp_dir[0]}_{tmp_dir[1]}_{tmp_dir[2]}_{tmp_end}_duplicated.png", bbox_inches='tight', pad_inches=0)
                    plt.close()
        last_counter += 15
        counter = last_counter
        while counter < m:
            curr_plot = self.plot(self.data.iloc[counter:counter+incr, :].copy(), benchmark)
            counter += counter_incr
            curr_dir = []
            for i in [5, 10, 15]:
                if counter + i + 1 < m:
                    if self.data.iloc[counter + i + 1, :]['close'] > self.data.iloc[counter + 1, :]['close']:
                        curr_dir.append(1)
                    else:
                        curr_dir.append(-1)
            if len(curr_dir) == 3:
                plt.imshow(curr_plot)
                plt.axis('off')
                plt.savefig(f"{test_name}/{self.symbol}_{self.window_size}_{self.freq}_{curr_dir[0]}_{curr_dir[1]}_{curr_dir[2]}_{self.data.index.values[counter]}_version_1.png", bbox_inches='tight', pad_inches=0)
                plt.close()

# %%
# d = data_generation('data/XNAS-20240629-DM3T6SKQVU/xnas-itch-20180501-20240628.ohlcv-1h.csv', 'H')
d = data_generation('yfinance_SPY.csv', freq='D')
ohlc = charts(data=d, symbol='SPY', freq='D', overlap=True)
ohlc.generate(benchmark=False, make_up_short=False)

# %%
# Get the list of S&P 500 companies from Wikipedia
sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
table = pd.read_html(sp500_url)
sp500_df = table[0]
tickers = sp500_df['Symbol'].tolist()

error_count = 0
error_list = []
for ticker in tickers:
    print(f"Working at {ticker}")
    try:
        d = data_generation(f'data-SPYstock/{ticker}.csv', freq='D')
        ohlc = charts(data=d, symbol=ticker, freq='D', overlap=True)
        ohlc.generate(benchmark=True, make_up_short=False)
        print(f"Generation complete for {ticker}")
    except:
        print(f"Error generating {ticker}")
        error_count += 1
        error_list.append(ticker)
# Out:
# Working at MMM
# Generation complete for MMM
# Working at AOS
# Error generating AOS
# Working at ABT
# Error generating ABT
# Working at ABBV
# Generation complete for ABBV
# Working at ACN
# Generation complete for ACN
# Working at ADBE
# Error generating ADBE
# Working at AMD
# Error generating AMD
# Working at AES
# Generation complete for AES
# Working at AFL
# Error generating AFL
# Working at A
# Generation complete for A
# Working at APD
# Error generating APD
# Working at ABNB
# Generation complete for ABNB
# Working at AKAM
# Generation complete for AKAM
# Working at ALB
# Generation complete for ALB
# Working at ARE
# Generation complete for ARE
# Working at ALGN
# Generation complete for ALGN
# Working at ALLE
# Generation complete for ALLE
# Working at LNT
# Error generating LNT
# Working at ALL
# Generation complete for ALL
# Working at GOOGL
# Generation complete for GOOGL
# Working at GOOG
# Generation complete for GOOG
# Working at MO
# Generation complete for MO
# Working at AMZN
# Generation complete for AMZN
# Working at AMCR
# Generation complete for AMCR
# Working at AEE
# Generation complete for AEE
# Working at AAL
# Generation complete for AAL
# Working at AEP
# Generation complete for AEP
# Working at AXP
# Generation complete for AXP
# Working at AIG
# Error generating AIG
# Working at AMT
# Generation complete for AMT
# Working at AWK
# Generation complete for AWK
# Working at AMP
# Generation complete for AMP
# Working at AME
# Generation complete for AME
# Working at AMGN
# Error generating AMGN
# Working at APH
# Generation complete for APH
# Working at ADI
# Error generating ADI
# Working at ANSS
# Generation complete for ANSS
# Working at AON
# Error generating AON
# Working at APA
# Generation complete for APA
# Working at AAPL
# Generation complete for AAPL
# Working at AMAT
# Error generating AMAT
# Working at APTV
# Generation complete for APTV
# Working at ACGL
# Generation complete for ACGL
# Working at ADM
# Error generating ADM
# Working at ANET
# Generation complete for ANET
# Working at AJG
# Error generating AJG
# Working at AIZ
# Generation complete for AIZ
# Working at T
# Error generating T
# Working at ATO
# Generation complete for ATO
# Working at ADSK
# Error generating ADSK
# Working at ADP
# Error generating ADP
# Working at AZO
# Generation complete for AZO
# Working at AVB
# Generation complete for AVB
# Working at AVY
# Error generating AVY
# Working at AXON
# Generation complete for AXON
# Working at BKR
# Error generating BKR
# Working at BALL
# Error generating BALL
# Working at BAC
# Error generating BAC
# Working at BK
# Generation complete for BK
# Working at BBWI
# Error generating BBWI
# Working at BAX
# Error generating BAX
# Working at BDX
# Error generating BDX
# Working at BRK.B
# Error generating BRK.B
# Working at BBY
# Error generating BBY
# Working at BIO
# Generation complete for BIO
# Working at TECH
# Error generating TECH
# Working at BIIB
# Generation complete for BIIB
# Working at BLK
# Generation complete for BLK
# Working at BX
# Generation complete for BX
# Working at BA
# Generation complete for BA
# Working at BKNG
# Generation complete for BKNG
# Working at BWA
# Generation complete for BWA
# Working at BXP
# Generation complete for BXP
# Working at BSX
# Generation complete for BSX
# Working at BMY
# Generation complete for BMY
# Working at AVGO
# Generation complete for AVGO
# Working at BR
# Generation complete for BR
# Working at BRO
# Error generating BRO
# Working at BF.B
# Error generating BF.B
# Working at BLDR
# Generation complete for BLDR
# Working at BG
# Generation complete for BG
# Working at CDNS
# Error generating CDNS
# Working at CZR
# Generation complete for CZR
# Working at CPT
# Generation complete for CPT
# Working at CPB
# Error generating CPB
# Working at COF
# Generation complete for COF
# Working at CAH
# Error generating CAH
# Working at KMX
# Generation complete for KMX
# Working at CCL
# Error generating CCL
# Working at CARR
# Generation complete for CARR
# Working at CTLT
# Generation complete for CTLT
# Working at CAT
# Generation complete for CAT
# Working at CBOE
# Generation complete for CBOE
# Working at CBRE
# Generation complete for CBRE
# Working at CDW
# Generation complete for CDW
# Working at CE
# Generation complete for CE
# Working at COR
# Generation complete for COR
# Working at CNC
# Generation complete for CNC
# Working at CNP
# Generation complete for CNP
# Working at CF
# Generation complete for CF
# Working at CHRW
# Generation complete for CHRW
# Working at CRL
# Generation complete for CRL
# Working at SCHW
# Error generating SCHW
# Working at CHTR
# Generation complete for CHTR
# Working at CVX
# Generation complete for CVX
# Working at CMG
# Generation complete for CMG
# Working at CB
# Generation complete for CB
# Working at CHD
# Error generating CHD
# Working at CI
# Generation complete for CI
# Working at CINF
# Error generating CINF
# Working at CTAS
# Error generating CTAS
# Working at CSCO
# Error generating CSCO
# Working at C
# Generation complete for C
# Working at CFG
# Generation complete for CFG
# Working at CLX
# Error generating CLX
# Working at CME
# Generation complete for CME
# Working at CMS
# Error generating CMS
# Working at KO
# Generation complete for KO
# Working at CTSH
# Generation complete for CTSH
# Working at CL
# Generation complete for CL
# Working at CMCSA
# Error generating CMCSA
# Working at CAG
# Error generating CAG
# Working at COP
# Generation complete for COP
# Working at ED
# Generation complete for ED
# Working at STZ
# Generation complete for STZ
# Working at CEG
# Generation complete for CEG
# Working at COO
# Error generating COO
# Working at CPRT
# Generation complete for CPRT
# Working at GLW
# Generation complete for GLW
# Working at CPAY
# Generation complete for CPAY
# Working at CTVA
# Generation complete for CTVA
# Working at CSGP
# Generation complete for CSGP
# Working at COST
# Generation complete for COST
# Working at CTRA
# Generation complete for CTRA
# Working at CRWD
# Generation complete for CRWD
# Working at CCI
# Generation complete for CCI
# Working at CSX
# Generation complete for CSX
# Working at CMI
# Error generating CMI
# Working at CVS
# Error generating CVS
# Working at DHR
# Error generating DHR
# Working at DRI
# Generation complete for DRI
# Working at DVA
# Generation complete for DVA
# Working at DAY
# Generation complete for DAY
# Working at DECK
# Generation complete for DECK
# Working at DE
# Generation complete for DE
# Working at DAL
# Generation complete for DAL
# Working at DVN
# Error generating DVN
# Working at DXCM
# Generation complete for DXCM
# Working at FANG
# Generation complete for FANG
# Working at DLR
# Generation complete for DLR
# Working at DFS
# Generation complete for DFS
# Working at DG
# Generation complete for DG
# Working at DLTR
# Generation complete for DLTR
# Working at D
# Error generating D
# Working at DPZ
# Generation complete for DPZ
# Working at DOV
# Error generating DOV
# Working at DOW
# Generation complete for DOW
# Working at DHI
# Generation complete for DHI
# Working at DTE
# Generation complete for DTE
# Working at DUK
# Error generating DUK
# Working at DD
# Generation complete for DD
# Working at EMN
# Generation complete for EMN
# Working at ETN
# Generation complete for ETN
# Working at EBAY
# Generation complete for EBAY
# Working at ECL
# Error generating ECL
# Working at EIX
# Generation complete for EIX
# Working at EW
# Generation complete for EW
# Working at EA
# Error generating EA
# Working at ELV
# Generation complete for ELV
# Working at LLY
# Generation complete for LLY
# Working at EMR
# Generation complete for EMR
# Working at ENPH
# Generation complete for ENPH
# Working at ETR
# Generation complete for ETR
# Working at EOG
# Generation complete for EOG
# Working at EPAM
# Generation complete for EPAM
# Working at EQT
# Error generating EQT
# Working at EFX
# Error generating EFX
# Working at EQIX
# Generation complete for EQIX
# Working at EQR
# Generation complete for EQR
# Working at ESS
# Generation complete for ESS
# Working at EL
# Generation complete for EL
# Working at ETSY
# Generation complete for ETSY
# Working at EG
# Generation complete for EG
# Working at EVRG
# Error generating EVRG
# Working at ES
# Error generating ES
# Working at EXC
# Generation complete for EXC
# Working at EXPE
# Generation complete for EXPE
# Working at EXPD
# Error generating EXPD
# Working at EXR
# Generation complete for EXR
# Working at XOM
# Generation complete for XOM
# Working at FFIV
# Generation complete for FFIV
# Working at FDS
# Generation complete for FDS
# Working at FICO
# Error generating FICO
# Working at FAST
# Error generating FAST
# Working at FRT
# Generation complete for FRT
# Working at FDX
# Generation complete for FDX
# Working at FIS
# Generation complete for FIS
# Working at FITB
# Error generating FITB
# Working at FSLR
# Generation complete for FSLR
# Working at FE
# Generation complete for FE
# Working at FI
# Error generating FI
# Working at FMC
# Error generating FMC
# Working at F
# Generation complete for F
# Working at FTNT
# Generation complete for FTNT
# Working at FTV
# Generation complete for FTV
# Working at FOXA
# Generation complete for FOXA
# Working at FOX
# Generation complete for FOX
# Working at BEN
# Error generating BEN
# Working at FCX
# Generation complete for FCX
# Working at GRMN
# Generation complete for GRMN
# Working at IT
# Generation complete for IT
# Working at GE
# Generation complete for GE
# Working at GEHC
# Generation complete for GEHC
# Working at GEV
# Generation complete for GEV
# Working at GEN
# Error generating GEN
# Working at GNRC
# Generation complete for GNRC
# Working at GD
# Generation complete for GD
# Working at GIS
# Error generating GIS
# Working at GM
# Generation complete for GM
# Working at GPC
# Error generating GPC
# Working at GILD
# Generation complete for GILD
# Working at GPN
# Generation complete for GPN
# Working at GL
# Error generating GL
# Working at GDDY
# Generation complete for GDDY
# Working at GS
# Generation complete for GS
# Working at HAL
# Generation complete for HAL
# Working at HIG
# Generation complete for HIG
# Working at HAS
# Error generating HAS
# Working at HCA
# Generation complete for HCA
# Working at DOC
# Error generating DOC
# Working at HSIC
# Generation complete for HSIC
# Working at HSY
# Error generating HSY
# Working at HES
# Error generating HES
# Working at HPE
# Generation complete for HPE
# Working at HLT
# Generation complete for HLT
# Working at HOLX
# Error generating HOLX
# Working at HD
# Generation complete for HD
# Working at HON
# Generation complete for HON
# Working at HRL
# Error generating HRL
# Working at HST
# Error generating HST
# Working at HWM
# Generation complete for HWM
# Working at HPQ
# Generation complete for HPQ
# Working at HUBB
# Error generating HUBB
# Working at HUM
# Generation complete for HUM
# Working at HBAN
# Error generating HBAN
# Working at HII
# Generation complete for HII
# Working at IBM
# Generation complete for IBM
# Working at IEX
# Error generating IEX
# Working at IDXX
# Error generating IDXX
# Working at ITW
# Error generating ITW
# Working at INCY
# Generation complete for INCY
# Working at IR
# Generation complete for IR
# Working at PODD
# Generation complete for PODD
# Working at INTC
# Generation complete for INTC
# Working at ICE
# Generation complete for ICE
# Working at IFF
# Error generating IFF
# Working at IP
# Generation complete for IP
# Working at IPG
# Error generating IPG
# Working at INTU
# Generation complete for INTU
# Working at ISRG
# Generation complete for ISRG
# Working at IVZ
# Generation complete for IVZ
# Working at INVH
# Generation complete for INVH
# Working at IQV
# Generation complete for IQV
# Working at IRM
# Generation complete for IRM
# Working at JBHT
# Error generating JBHT
# Working at JBL
# Generation complete for JBL
# Working at JKHY
# Error generating JKHY
# Working at J
# Error generating J
# Working at JNJ
# Generation complete for JNJ
# Working at JCI
# Generation complete for JCI
# Working at JPM
# Error generating JPM
# Working at JNPR
# Generation complete for JNPR
# Working at K
# Error generating K
# Working at KVUE
# Generation complete for KVUE
# Working at KDP
# Generation complete for KDP
# Working at KEY
# Generation complete for KEY
# Working at KEYS
# Generation complete for KEYS
# Working at KMB
# Error generating KMB
# Working at KIM
# Generation complete for KIM
# Working at KMI
# Generation complete for KMI
# Working at KKR
# Generation complete for KKR
# Working at KLAC
# Error generating KLAC
# Working at KHC
# Generation complete for KHC
# Working at KR
# Generation complete for KR
# Working at LHX
# Generation complete for LHX
# Working at LH
# Generation complete for LH
# Working at LRCX
# Error generating LRCX
# Working at LW
# Generation complete for LW
# Working at LVS
# Generation complete for LVS
# Working at LDOS
# Generation complete for LDOS
# Working at LEN
# Error generating LEN
# Working at LIN
# Generation complete for LIN
# Working at LYV
# Generation complete for LYV
# Working at LKQ
# Generation complete for LKQ
# Working at LMT
# Generation complete for LMT
# Working at L
# Error generating L
# Working at LOW
# Error generating LOW
# Working at LULU
# Generation complete for LULU
# Working at LYB
# Generation complete for LYB
# Working at MTB
# Error generating MTB
# Working at MRO
# Generation complete for MRO
# Working at MPC
# Generation complete for MPC
# Working at MKTX
# Generation complete for MKTX
# Working at MAR
# Generation complete for MAR
# Working at MMC
# Error generating MMC
# Working at MLM
# Generation complete for MLM
# Working at MAS
# Error generating MAS
# Working at MA
# Generation complete for MA
# Working at MTCH
# Generation complete for MTCH
# Working at MKC
# Error generating MKC
# Working at MCD
# Generation complete for MCD
# Working at MCK
# Generation complete for MCK
# Working at MDT
# Error generating MDT
# Working at MRK
# Generation complete for MRK
# Working at META
# Generation complete for META
# Working at MET
# Generation complete for MET
# Working at MTD
# Generation complete for MTD
# Working at MGM
# Error generating MGM
# Working at MCHP
# Generation complete for MCHP
# Working at MU
# Error generating MU
# Working at MSFT
# Generation complete for MSFT
# Working at MAA
# Generation complete for MAA
# Working at MRNA
# Generation complete for MRNA
# Working at MHK
# Generation complete for MHK
# Working at MOH
# Generation complete for MOH
# Working at TAP
# Error generating TAP
# Working at MDLZ
# Generation complete for MDLZ
# Working at MPWR
# Generation complete for MPWR
# Working at MNST
# Error generating MNST
# Working at MCO
# Generation complete for MCO
# Working at MS
# Generation complete for MS
# Working at MOS
# Generation complete for MOS
# Working at MSI
# Generation complete for MSI
# Working at MSCI
# Generation complete for MSCI
# Working at NDAQ
# Generation complete for NDAQ
# Working at NTAP
# Generation complete for NTAP
# Working at NFLX
# Generation complete for NFLX
# Working at NEM
# Error generating NEM
# Working at NWSA
# Generation complete for NWSA
# Working at NWS
# Generation complete for NWS
# Working at NEE
# Error generating NEE
# Working at NKE
# Generation complete for NKE
# Working at NI
# Error generating NI
# Working at NDSN
# Error generating NDSN
# Working at NSC
# Generation complete for NSC
# Working at NTRS
# Error generating NTRS
# Working at NOC
# Generation complete for NOC
# Working at NCLH
# Generation complete for NCLH
# Working at NRG
# Generation complete for NRG
# Working at NUE
# Error generating NUE
# Working at NVDA
# Generation complete for NVDA
# Working at NVR
# Generation complete for NVR
# Working at NXPI
# Generation complete for NXPI
# Working at ORLY
# Generation complete for ORLY
# Working at OXY
# Generation complete for OXY
# Working at ODFL
# Generation complete for ODFL
# Working at OMC
# Error generating OMC
# Working at ON
# Generation complete for ON
# Working at OKE
# Error generating OKE
# Working at ORCL
# Generation complete for ORCL
# Working at OTIS
# Generation complete for OTIS
# Working at PCAR
# Error generating PCAR
# Working at PKG
# Generation complete for PKG
# Working at PANW
# Generation complete for PANW
# Working at PARA
# Generation complete for PARA
# Working at PH
# Error generating PH
# Working at PAYX
# Error generating PAYX
# Working at PAYC
# Generation complete for PAYC
# Working at PYPL
# Generation complete for PYPL
# Working at PNR
# Generation complete for PNR
# Working at PEP
# Generation complete for PEP
# Working at PFE
# Generation complete for PFE
# Working at PCG
# Generation complete for PCG
# Working at PM
# Generation complete for PM
# Working at PSX
# Generation complete for PSX
# Working at PNW
# Error generating PNW
# Working at PNC
# Error generating PNC
# Working at POOL
# Generation complete for POOL
# Working at PPG
# Error generating PPG
# Working at PPL
# Error generating PPL
# Working at PFG
# Generation complete for PFG
# Working at PG
# Generation complete for PG
# Working at PGR
# Error generating PGR
# Working at PLD
# Generation complete for PLD
# Working at PRU
# Generation complete for PRU
# Working at PEG
# Generation complete for PEG
# Working at PTC
# Error generating PTC
# Working at PSA
# Generation complete for PSA
# Working at PHM
# Error generating PHM
# Working at QRVO
# Generation complete for QRVO
# Working at PWR
# Generation complete for PWR
# Working at QCOM
# Generation complete for QCOM
# Working at DGX
# Generation complete for DGX
# Working at RL
# Generation complete for RL
# Working at RJF
# Error generating RJF
# Working at RTX
# Generation complete for RTX
# Working at O
# Generation complete for O
# Working at REG
# Generation complete for REG
# Working at REGN
# Generation complete for REGN
# Working at RF
# Error generating RF
# Working at RSG
# Generation complete for RSG
# Working at RMD
# Generation complete for RMD
# Working at RVTY
# Error generating RVTY
# Working at ROK
# Generation complete for ROK
# Working at ROL
# Error generating ROL
# Working at ROP
# Generation complete for ROP
# Working at ROST
# Error generating ROST
# Working at RCL
# Generation complete for RCL
# Working at SPGI
# Error generating SPGI
# Working at CRM
# Generation complete for CRM
# Working at SBAC
# Generation complete for SBAC
# Working at SLB
# Generation complete for SLB
# Working at STX
# Generation complete for STX
# Working at SRE
# Generation complete for SRE
# Working at NOW
# Generation complete for NOW
# Working at SHW
# Error generating SHW
# Working at SPG
# Generation complete for SPG
# Working at SWKS
# Generation complete for SWKS
# Working at SJM
# Generation complete for SJM
# Working at SNA
# Error generating SNA
# Working at SOLV
# Generation complete for SOLV
# Working at SO
# Generation complete for SO
# Working at LUV
# Generation complete for LUV
# Working at SWK
# Error generating SWK
# Working at SBUX
# Generation complete for SBUX
# Working at STT
# Error generating STT
# Working at STLD
# Generation complete for STLD
# Working at STE
# Generation complete for STE
# Working at SYK
# Error generating SYK
# Working at SMCI
# Generation complete for SMCI
# Working at SYF
# Generation complete for SYF
# Working at SNPS
# Generation complete for SNPS
# Working at SYY
# Generation complete for SYY
# Working at TMUS
# Generation complete for TMUS
# Working at TROW
# Error generating TROW
# Working at TTWO
# Generation complete for TTWO
# Working at TPR
# Generation complete for TPR
# Working at TRGP
# Generation complete for TRGP
# Working at TGT
# Error generating TGT
# Working at TEL
# Generation complete for TEL
# Working at TDY
# Generation complete for TDY
# Working at TFX
# Error generating TFX
# Working at TER
# Error generating TER
# Working at TSLA
# Generation complete for TSLA
# Working at TXN
# Generation complete for TXN
# Working at TXT
# Error generating TXT
# Working at TMO
# Error generating TMO
# Working at TJX
# Error generating TJX
# Working at TSCO
# Generation complete for TSCO
# Working at TT
# Error generating TT
# Working at TDG
# Generation complete for TDG
# Working at TRV
# Error generating TRV
# Working at TRMB
# Error generating TRMB
# Working at TFC
# Error generating TFC
# Working at TYL
# Error generating TYL
# Working at TSN
# Error generating TSN
# Working at USB
# Generation complete for USB
# Working at UBER
# Generation complete for UBER
# Working at UDR
# Error generating UDR
# Working at ULTA
# Generation complete for ULTA
# Working at UNP
# Generation complete for UNP
# Working at UAL
# Generation complete for UAL
# Working at UPS
# Generation complete for UPS
# Working at URI
# Generation complete for URI
# Working at UNH
# Error generating UNH
# Working at UHS
# Error generating UHS
# Working at VLO
# Generation complete for VLO
# Working at VTR
# Generation complete for VTR
# Working at VLTO
# Generation complete for VLTO
# Working at VRSN
# Generation complete for VRSN
# Working at VRSK
# Generation complete for VRSK
# Working at VZ
# Generation complete for VZ
# Working at VRTX
# Generation complete for VRTX
# Working at VTRS
# Error generating VTRS
# Working at VICI
# Generation complete for VICI
# Working at V
# Generation complete for V
# Working at VST
# Generation complete for VST
# Working at VMC
# Error generating VMC
# Working at WRB
# Error generating WRB
# Working at GWW
# Error generating GWW
# Working at WAB
# Generation complete for WAB
# Working at WBA
# Error generating WBA
# Working at WMT
# Generation complete for WMT
# Working at DIS
# Generation complete for DIS
# Working at WBD
# Generation complete for WBD
# Working at WM
# Error generating WM
# Working at WAT
# Generation complete for WAT
# Working at WEC
# Error generating WEC
# Working at WFC
# Generation complete for WFC
# Working at WELL
# Error generating WELL
# Working at WST
# Error generating WST
# Working at WDC
# Error generating WDC
# Working at WRK
# Generation complete for WRK
# Working at WY
# Generation complete for WY
# Working at WMB
# Generation complete for WMB
# Working at WTW
# Generation complete for WTW
# Working at WYNN
# Generation complete for WYNN
# Working at XEL
# Error generating XEL
# Working at XYL
# Generation complete for XYL
# Working at YUM
# Generation complete for YUM
# Working at ZBRA
# Generation complete for ZBRA
# Working at ZBH
# Generation complete for ZBH
# Working at ZTS
# Generation complete for ZTS
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
error_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 error_count
#
# NameError: name 'error_count' is not defined
